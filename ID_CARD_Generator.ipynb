# %% [markdown]
# <a href="https://colab.research.google.com/github/S-ELANGO/Python/blob/main/ID_CARD_Generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install qrcode

# %%
from PIL import Image,ImageDraw,ImageFont
import random
import os
import datetime
import qrcode

# %%
image =Image.new('RGB',(1000,900),(255,255,255))
draw=ImageDraw.Draw(image)

# %%
font = ImageFont.truetype('LiberationSans-Regular.ttf',size=45)

# %%
d_date = datetime.datetime.now()
reg_format_date = d_date.strftime("%Y-%m-%d \t ID Card Generator \t %H:%M:%S %p")
print(reg_format_date)
# Out:
# 2025-12-23 	 ID Card Generator 	 15:35:37 PM

# %%
print('\n\nAll Fields are Mandatory')
print('Avoid any kind of Spelling Mistakes')
print('Write Everything in uppercase letters')
(x, y) = (50, 50)
message = input('\nEnter Your Company Name: ')
company=message
color = 'rgb(0, 0, 0)'
font = ImageFont.truetype('LiberationSans-Regular.ttf', size=80)
draw.text((x, y), message, fill=color, font=font)
# Out:
# All Fields are Mandatory
# Avoid any kind of Spelling Mistakes
# Write Everything in uppercase letters
#
# Enter Your Company Name: zoho

# %%
# adding an unique id number. You can manually take it from user
(x, y) = (600, 75)
idno=random.randint(10000000,90000000)
message = str('ID '+str(idno))
color = 'rgb(0, 0, 0)' # black color
font = ImageFont.truetype('LiberationSans-Regular.ttf', size=60)
draw.text((x, y), message, fill=color, font=font)

# %%
(x, y) = (50, 250)
message = input('Enter Your Full Name: ')
name=message
color = 'rgb(0, 0, 0)' # black color
font = ImageFont.truetype('LiberationSans-Regular.ttf', size=45)
draw.text((x, y), message, fill=color, font=font)
# Out:
# Enter Your Full Name: elango.s

# %%
(x, y) = (50, 350)
message = input('Enter Your Gender: ')
color = 'rgb(0, 0, 0)' # black color
draw.text((x, y), message, fill=color, font=font)
(x, y) = (250, 350)
message = input('Enter Your Age: ')
color = 'rgb(0, 0, 0)' # black color
draw.text((x, y), message, fill=color, font=font)
# Out:
# Enter Your Gender: male
# Enter Your Age: 20

# %%
(x, y) = (50, 450)
message = input('Enter Your Date Of Birth: ')
color = 'rgb(0, 0, 0)' # black color
draw.text((x, y), message, fill=color, font=font)
# Out:
# Enter Your Date Of Birth: 21\03\2006

# %%
(x, y) = (50, 550)
message = input('Enter Your Blood Group: ')
color = 'rgb(255, 0, 0)' # black color
draw.text((x, y), message, fill=color, font=font)
# Out:
# Enter Your Blood Group: o+

# %%
(x, y) = (50, 650)
message = input('Enter Your Mobile Number: ')
temp=message
color = 'rgb(0, 0, 0)' # black color
draw.text((x, y), message, fill=color, font=font)
# Out:
# Enter Your Mobile Number: 999422759

# %%
(x, y) = (50, 750)
message = input('Enter Your Address: ')
color = 'rgb(0, 0, 0)' # black color
draw.text((x, y), message, fill=color, font=font)
# Out:
# Enter Your Address: erode

# %%
image.save(str(name)+'.png')

# %%
img = qrcode.make(str(company)+str(idno))   # this info. is added in QR code, also add other things
img.save(str(idno)+'.bmp')

# %%
til = Image.open(name+'.png')
im = Image.open(str(idno)+'.bmp') #25x25
til.paste(im,(600,350))
til.save(name+'.png')

# %%
til.show()

# %%
print(f'''


Your ID Card Successfully created in a PNG file {name}.png''')
input('\n\nPress any key to Close program...')
# Out:
# Your ID Card Successfully created in a PNG file elango.s.png
#
#
# Press any key to Close program...p
# 'p'
